# %% [markdown]
# <a href="https://colab.research.google.com/github/novoforce/ai_for_sustainability/blob/master/1_ClassificationProblem_cifar10_aug.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install http://download.pytorch.org/whl/cu80/torch-0.3.0.post4-cp36-cp36m-linux_x86_64.whl 
# !pip3 install torchvision
# !pip3 install torchsummary

# %%
import torch
import numpy as np
from torchsummary import summary
train_on_gpu = torch.cuda.is_available()
if train_on_gpu:
  print("The GPU is available for training")
else:
    print("The GPU is not available for training")
# Out:
# The GPU is available for training

# %%
#loading the datasets
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data.sampler import SubsetRandomSampler
#https://pytorch.org/docs/stable/torchvision/transforms.html --for the reference
transform = transforms.Compose([
    transforms.RandomHorizontalFlip(), # randomly flip and rotate
    transforms.RandomRotation(10),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])

train_data = datasets.CIFAR10('data', train=True,
                              download=True, transform=transform)
test_data = datasets.CIFAR10('data', train=False,
                             download=True, transform=transform)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
valid_size = 0.2# 20% of the training data is taken for the testing
num_train = len(train_data)
indices = list(range(num_train))
# print(indices)
np.random.shuffle(indices)#shuffling is done so as to get a mixed training and the testing sample
split = int(np.floor(valid_size * num_train))
train_idx, valid_idx = indices[split:], indices[:split]

# %%
#this will create a training and the testing batches for the model
train_sampler = SubsetRandomSampler(train_idx)
valid_sampler = SubsetRandomSampler(valid_idx)

# %%
from torch.utils.data import DataLoader
train_loader = DataLoader(train_data, batch_size=20,sampler=train_sampler)
valid_loader = DataLoader(train_data, batch_size=20,sampler=valid_sampler)
test_loader = DataLoader(test_data,batch_size=20)

# %%
classes = ['airplane', 'automobile', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck']

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def imshow(img):
  img = img / 2 + 0.5  # unnormalize
  plt.imshow(np.transpose(img, (1, 2, 0)))  # convert from Tensor image

# %%
#visualize the training data
dataiter = iter(train_loader)#making the iterator out of train_loader
images, labels = dataiter.next()#takinng the next batch
images = images.numpy() # convert images to numpy for display

# %%
# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(25, 4))
# display 20 images
for idx in np.arange(20):
    ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])#rows,columns
    imshow(images[idx])
    ax.set_title(classes[labels[idx]])

# %%
# refer:  https://pytorch.org/docs/stable/nn.html#conv2d

'''
OUTPUT SIZE =  (W−F+2P)/S+1.

W = INPUT SIZE
F = KERNAL SIZE
P = PADDING
S = STRIDE
'''

#define the network
import torch.nn as nn
import torch.nn.functional as F

class Net(nn.Module):
  def __init__(self):
    super(Net, self).__init__()
    # convolutional layer (sees 32x32x3 image tensor)
    self.conv1 = nn.Conv2d(3, 16, 3, padding=1)
    # convolutional layer (sees 16x16x16 tensor)
    self.conv2 = nn.Conv2d(16, 32, 3, padding=1)
    # convolutional layer (sees 8x8x32 tensor)
    self.conv3 = nn.Conv2d(32, 64, 3, padding=1)
    # max pooling layer
    self.pool = nn.MaxPool2d(2, 2)
    # linear layer (64 * 4 * 4 -> 500)
    self.fc1 = nn.Linear(64 * 4 * 4, 500)
    # linear layer (500 -> 10)
    self.fc2 = nn.Linear(500, len(classes))
    # dropout layer (p=0.25)
    self.dropout = nn.Dropout(0.25)


  def forward(self,x):
    '''
    first block
    '''
    x = self.conv1(x)#<--(32,32,3) (3x3) -->(32,32,16)
    x = F.relu(x)
    x = self.pool(x)#<--(32,32,16) !(2x2)! -->(16,16,16)
    '''
    second block
    '''
    x = self.conv2(x)#<--(16,16,16) (3x3) -->(16,16,32)
    x = F.relu(x)
    x = self.pool(x)#<--(16,16,32) !(2x2)! -->(8,8,32)
    '''
    third block
    '''
    x = self.conv3(x)#<--(8,8,32) (3x3) -->(8,8,64)
    x = F.relu(x)
    x = self.pool(x)#<--(8,8,64) !(2x2)! -->(4,4,64)
    '''
    fully connected layer
    '''
    x = x.view(-1,64*4*4)#the output size will be (1,64*4*4)
    x = self.dropout(x)
    x = self.fc1(x)#<--(1,1024) -->(1,500)
    x = F.relu(x)
    x = self.dropout(x)
    x = self.fc2(x)#<--(1,500) -->(1,10)
    return x

# %%
model = Net()#setting the model object

# %%
#transferring the model to the GPU
if train_on_gpu:
  model.cuda()
summary(model,(3,32,32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 32, 32]             448
#          MaxPool2d-2           [-1, 16, 16, 16]               0
#             Conv2d-3           [-1, 32, 16, 16]           4,640
#          MaxPool2d-4             [-1, 32, 8, 8]               0
#             Conv2d-5             [-1, 64, 8, 8]          18,496
#          MaxPool2d-6             [-1, 64, 4, 4]               0
#            Dropout-7                 [-1, 1024]               0
#             Linear-8                  [-1, 500]         512,500
#            Dropout-9                  [-1, 500]               0
#            Linear-10                   [-1, 10]           5,010
# ================================================================
# Total params: 541,094
# Trainable params: 541,094
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.29
# Params size (MB): 2.06
# Estimated Total Size (MB): 2.36
# ----------------------------------------------------------------

# %%
#defining the loss function and the optimizer
import torch.optim as optim
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

# %%
#training the network
epochs = 30
valid_loss_min = np.inf #setting the validation loss to infinity

for epoch in range(1,epochs+1):
  train_loss = 0.0
  valid_loss = 0.0

  model.train()#setting the model to train mode

  for data,target in train_loader:
    if train_on_gpu:
      data, target = data.cuda(), target.cuda()

    optimizer.zero_grad()#clearing out any accumulated gradients
    output = model(data)
    loss = criterion(output,target)
    loss.backward()
    optimizer.step()
    train_loss+= loss.item()*data.size(0)

#Validation mode
  model.eval()#setting the model to eval mode as the model is evaluated on the validation set 
  for data,target in valid_loader:
    if train_on_gpu:
        data, target = data.cuda(), target.cuda()

    output = model(data)
    loss = criterion(output,target)
    valid_loss += loss.item()*data.size(0)

    #for calculating the average loss
    train_loss = train_loss/len(train_loader.sampler)
    valid_loss = valid_loss/len(valid_loader.sampler)

    print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(epoch, train_loss, valid_loss))
    # save model if validation loss has decreased
    if valid_loss <= valid_loss_min:
      print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(valid_loss_min,valid_loss))
      torch.save(model.state_dict(), 'model_cifar_aug.pt')
      valid_loss_min = valid_loss
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001572
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001716
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001732
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001144
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001510
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000730
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000906
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001340
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001605
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001861
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001461
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001182
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001484
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001118
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000649
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001549
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000863
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001715
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001967
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001444
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001602
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.002174
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001144
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000810
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001441
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000823
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001135
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.002183
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.002840
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.002053
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.002136
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001868
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001497
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001155
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001052
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001125
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001137
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.002097
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001217
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001896
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001110
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001593
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.002124
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001357
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000843
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001322
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001917
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001867
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001156
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001254
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001139
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001421
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000866
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000455
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000920
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001349
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.002240
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001613
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001232
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001493
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000757
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001412
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001652
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001356
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001398
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001699
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001193
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001683
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001546
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000931
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001829
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000900
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001072
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001671
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000970
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001563
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001437
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000896
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.002024
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001156
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001939
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000913
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001004
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001952
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001819
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000958
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000818
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001000
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001135
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001648
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001653
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001717
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001305
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001082
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001189
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001281
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001074
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000946
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001088
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001325
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001476
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001212
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001128
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001929
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001089
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000935
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001122
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001453
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001052
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001410
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001698
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001158
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.002044
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001083
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001281
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001279
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001811
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001518
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001317
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001824
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001959
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001135
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.002222
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001859
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001970
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001018
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001906
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001591
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001271
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000679
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001262
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001202
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001123
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001938
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001685
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001081
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000646
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000925
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001337
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001317
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.002022
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001794
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001618
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001466
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001462
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001149
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001564
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001218
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001886
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.002012
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000997
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001517
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000983
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001952
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000809
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001155
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000901
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001563
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001372
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001329
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.002465
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001327
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000994
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001368
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001329
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001519
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.002531
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001926
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001538
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001968
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001759
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000968
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001164
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001420
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.002203
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001677
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001591
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001568
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001811
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000993
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001432
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001663
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.002235
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.002007
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.002013
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.003104
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001403
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001775
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001569
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001167
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001572
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001980
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001044
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001343
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001654
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001019
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001602
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.002178
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001388
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.002357
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.002267
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001370
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001588
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.002468
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001839
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000728
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001560
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001387
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001336
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001688
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001581
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001258
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001444
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001286
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001428
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001962
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.002249
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000972
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001599
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001907
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001996
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.002256
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001486
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001269
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001620
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000832
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001191
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.003041
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001034
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001151
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001242
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001196
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.002341
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001369
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001811
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001686
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001688
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001221
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001188
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000927
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001318
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001626
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.002340
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001170
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001176
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.002024
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001519
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001602
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001479
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001595
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001443
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001215
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001218
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001858
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001186
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001159
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001409
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001761
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001503
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001000
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001452
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001845
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001738
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001502
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000973
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001051
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001229
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.002046
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001424
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001667
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001685
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001445
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.002432
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001383
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001036
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001882
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.002227
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001376
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001315
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000814
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001909
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001612
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.002547
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001765
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001523
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.002197
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001555
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001363
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001232
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001236
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000766
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001629
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001008
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001730
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001257
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001556
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001982
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.002208
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001513
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001821
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001015
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001417
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001072
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001554
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001702
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001292
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001330
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001129
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001524
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001079
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001449
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001753
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001167
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001521
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001774
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001501
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.002137
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001274
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001611
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.002205
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001496
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001536
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000701
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001616
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001504
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.002328
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001334
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001514
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000997
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.002303
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001853
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001626
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001196
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001109
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001471
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.002142
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001224
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001733
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000721
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001184
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001689
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000894
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001852
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001583
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001637
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001207
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000811
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001200
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001174
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001813
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001684
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.002390
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001560
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001849
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001202
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001527
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001164
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001475
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001998
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.002324
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001494
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001472
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.002183
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000645
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.002169
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001058
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001580
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001756
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001052
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001523
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.002133
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000855
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001538
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001397
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000945
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.002018
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.002315
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000647
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001870
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001370
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000984
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001149
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001382
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.002254
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001206
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001911
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001373
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001064
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.002085
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.002197
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001148
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001619
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001601
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001985
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001190
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001011
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001721
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001331
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001514
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001295
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001671
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.002519
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001113
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.002052
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001545
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001458
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001616
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001061
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001678
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000954
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001042
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000650
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000823
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001179
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001554
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.002034
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001201
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000775
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001931
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000645
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000805
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001378
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001551
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000740
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001401
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000900
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001624
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001881
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001907
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001069
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.002055
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001385
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001459
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001193
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001140
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001738
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001443
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001874
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.002249
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001108
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001289
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001758
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001374
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001816
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001204
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001435
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.002230
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001750
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001201
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001299
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000950
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001032
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001240
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000936
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001570
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001878
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001502
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001289
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001369
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001104
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000964
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001643
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001107
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001594
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001875
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.002001
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001681
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001766
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001984
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000769
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001549
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001795
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001192
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001451
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001380
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001108
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001685
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001152
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001367
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001432
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001327
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001468
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001468
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001929
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001504
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001512
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001363
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001766
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001472
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001869
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001652
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.002449
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001440
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.000824
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.002042
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001744
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001455
# Epoch: 21 	Training Loss: 0.000000 	Validation Loss: 0.001010
# Epoch: 22 	Training Loss: 0.715004 	Validation Loss: 0.000866
# Epoch: 22 	Training Loss: 0.000018 	Validation Loss: 0.001612
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001850
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.002031
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001838
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001859
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001212
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.000799
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001128
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001949
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001013
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.002684
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001245
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001248
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.000924
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001388
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001243
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.000717
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001866
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001346
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001668
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001511
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001441
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.000788
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001431
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001635
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001884
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.000738
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001258
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001607
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001926
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001701
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001923
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001886
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001621
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.002096
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.002240
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001795
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.000677
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001904
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.000917
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001331
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001065
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001820
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001276
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001184
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.000956
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001912
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001306
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001037
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.002382
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.002420
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.000966
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.000920
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001014
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001260
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001410
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001023
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001198
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001753
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001408
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.002300
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001069
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001560
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001554
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001258
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.002320
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001277
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.000833
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001053
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001481
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.002263
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001843
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.002062
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001559
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.002120
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.003001
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001166
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001066
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001199
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001184
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.000923
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001642
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001756
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001865
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001247
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001796
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001454
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.000672
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001927
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001439
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.000978
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001766
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.002397
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.000864
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001413
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001287
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001228
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.002274
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001542
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.000957
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001579
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001538
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001750
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001720
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.000637
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.002076
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.002347
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001404
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001351
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001376
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001723
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.000913
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001946
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001100
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.000937
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001198
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001449
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.002007
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001642
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001234
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001760
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001009
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.002011
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.000827
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.000936
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001569
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001614
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001004
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001386
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.000684
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001816
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001848
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001522
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001588
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.000925
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.000952
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001129
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001412
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001645
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001399
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.000737
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001244
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.000682
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001563
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.000965
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001406
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.000788
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001242
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.000790
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001109
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001613
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001757
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.000941
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001483
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001512
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001315
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.000928
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001596
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001001
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.000983
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001420
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001862
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001643
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001920
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001019
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001983
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001024
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001445
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001864
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001319
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001405
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001398
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.002502
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001706
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001337
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001488
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001694
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001491
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001251
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001136
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001749
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001244
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001474
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001758
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.002116
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001343
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001364
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.000691
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.000850
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001317
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001932
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001196
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001028
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.000945
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.000970
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001412
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001699
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001731
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.002042
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001723
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001973
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001028
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001713
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001672
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.002372
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001325
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001373
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001420
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001511
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001996
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001513
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001372
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001308
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.000696
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001349
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.000907
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001226
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.002152
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.000988
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.002001
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.000825
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001537
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.000934
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001551
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001457
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.002129
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.000979
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001545
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001220
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001598
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001120
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001582
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001476
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001297
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.002269
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001563
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001132
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001711
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001405
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001292
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001639
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001300
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001599
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001670
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001228
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001890
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001896
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.000549
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001378
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001421
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001763
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001549
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.002058
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001223
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001542
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001865
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.002061
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001440
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001723
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.000905
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001604
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.000613
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001599
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001288
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001728
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001622
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001241
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001779
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001091
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001516
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.000941
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001144
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001011
# Epoch: 22 	Training Loss: 0.000000 	Validation Loss: 0.001764
# ...
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001296
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001546
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001859
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.000866
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001493
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001297
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001778
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.002173
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001422
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.002048
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.002001
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001513
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.002188
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001724
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001678
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001332
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001801
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001003
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.002147
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001728
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001876
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001629
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.000871
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001363
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001273
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001223
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001303
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001645
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001457
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001205
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001587
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001207
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001055
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001373
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001544
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001309
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.000712
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001325
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001774
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001373
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001453
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001165
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001333
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001022
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001288
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001503
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001661
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001470
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001533
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001275
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001732
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001619
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001315
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001392
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001430
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001224
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001870
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001476
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001346
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001147
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001858
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001234
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001061
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001191
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001879
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.002298
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001253
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001529
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.000909
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001480
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001652
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.000759
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001042
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001253
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001080
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001701
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001594
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.002762
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001677
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001456
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001526
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001437
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.000713
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001779
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.002344
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.000896
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001577
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001963
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.002050
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.002120
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001563
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001487
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001164
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.000896
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001394
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.000927
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001014
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001487
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.002196
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.000711
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.000868
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001657
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001084
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001032
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.000856
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.000894
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001368
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.000862
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001236
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.000852
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001760
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.000680
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001233
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001300
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001173
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001776
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001241
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001568
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.000835
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.002254
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001730
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.000984
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001805
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001350
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.000498
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001102
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.000615
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001207
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001371
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001769
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001598
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001470
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.000854
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001616
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001594
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.000657
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001218
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001980
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001168
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001127
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.000887
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001375
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.000935
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001384
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001603
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.000635
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001262
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.002827
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001297
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.000585
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001226
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001062
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001202
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001692
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001195
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.000938
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001056
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001098
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001692
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001464
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001589
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001062
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001258
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001728
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001037
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.000965
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001360
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001380
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001735
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001947
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001502
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.000731
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001542
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.000959
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001647
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.000996
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001212
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001650
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001207
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001661
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001723
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.000858
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001127
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001147
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.002277
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001120
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001068
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001552
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001331
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001264
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001287
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001241
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001087
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001277
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001887
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.002007
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.000972
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001515
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001787
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.000642
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.000993
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001908
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001022
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.000932
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001013
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001016
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001252
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.000983
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001318
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.002505
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.000752
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001278
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001913
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.000978
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.000756
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.000640
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.000665
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001598
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001364
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.000895
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.000871
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001927
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001863
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001387
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.000921
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001744
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001154
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.000935
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001129
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001554
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001968
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001002
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001590
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001487
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.000617
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001336
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001224
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.000909
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.000507
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001373
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.000903
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001234
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001535
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001708
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001439
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001175
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001573
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.000869
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.000781
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001512
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001496
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.002026
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.000922
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.000994
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001057
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001175
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.001603
# Epoch: 30 	Training Loss: 0.000000 	Validation Loss: 0.000892

# %%
#loading the saved model
model.load_state_dict(torch.load('model_cifar_aug.pt'))
# Out:
# <All keys matched successfully>

# %%
#Testing the network
test_loss = 0.0
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
batch_size = 20

model.eval()
# iterate over test data
for data, target in test_loader:
    # move tensors to GPU if CUDA is available
    if train_on_gpu:
        data, target = data.cuda(), target.cuda()
    # forward pass: compute predicted outputs by passing inputs to the model
    output = model(data)
    # calculate the batch loss
    loss = criterion(output, target)
    # update test loss 
    test_loss += loss.item()*data.size(0)
    # convert output probabilities to predicted class
    _, pred = torch.max(output, 1)    
    # compare predictions to true label
    correct_tensor = pred.eq(target.data.view_as(pred))
    correct = np.squeeze(correct_tensor.numpy()) if not train_on_gpu else np.squeeze(correct_tensor.cpu().numpy())
    # calculate test accuracy for each object class
    for i in range(batch_size):
        label = target.data[i]
        class_correct[label] += correct[i].item()
        class_total[label] += 1
# average test loss
test_loss = test_loss/len(test_loader.dataset)
print('Test Loss: {:.6f}\n'.format(test_loss))

for i in range(10):
    if class_total[i] > 0:
        print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (classes[i], 100 * class_correct[i] / class_total[i],np.sum(class_correct[i]), np.sum(class_total[i])))
    else:
        print('Test Accuracy of %5s: N/A (no training examples)' % (classes[i]))

print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % (100. * np.sum(class_correct) / np.sum(class_total),np.sum(class_correct), np.sum(class_total)))
# Out:
# Test Loss: 0.689150
#
# Test Accuracy of airplane: 81% (817/1000)
# Test Accuracy of automobile: 86% (868/1000)
# Test Accuracy of  bird: 57% (575/1000)
# Test Accuracy of   cat: 58% (586/1000)
# Test Accuracy of  deer: 73% (734/1000)
# Test Accuracy of   dog: 70% (704/1000)
# Test Accuracy of  frog: 85% (852/1000)
# Test Accuracy of horse: 77% (774/1000)
# Test Accuracy of  ship: 84% (846/1000)
# Test Accuracy of truck: 82% (820/1000)
#
# Test Accuracy (Overall): 75% (7576/10000)

# %%
dataiter = iter(test_loader)
images, labels = dataiter.next()
images.numpy()

# move model inputs to cuda, if GPU available
if train_on_gpu:
    images = images.cuda()

# get sample outputs
output = model(images)
# convert output probabilities to predicted class
_, preds_tensor = torch.max(output, 1)
preds = np.squeeze(preds_tensor.numpy()) if not train_on_gpu else np.squeeze(preds_tensor.cpu().numpy())

# plot the images in the batch, along with predicted and true labels
fig = plt.figure(figsize=(25, 4))
for idx in np.arange(20):
    ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
    imshow(images.cpu()[idx])
    ax.set_title("{} ({})".format(classes[preds[idx]], classes[labels[idx]]),
                 color=("green" if preds[idx]==labels[idx].item() else "red"))
